# %%
from cbed_sim_workflow.cbed_simulation import contrast_stretch, atomic_potential, parse_xyz, overall_wrapper
from jax import numpy as jnp
import matplotlib.pyplot as plt

# %%
# !tar -xvzf C:/Users/zwx/Downloads/New_Bi2Se3_layered.tar.gz -C New_Bi2Se3_layered/
# Out:
# x ._ADHK_Bi2Se3.0
# x ADHK_Bi2Se3.0
# x ._ADHK_Bi2Se3.1
# x ADHK_Bi2Se3.1
# x ._ADHK_Bi2Se3.10
# x ADHK_Bi2Se3.10
# x ._ADHK_Bi2Se3.100
# x ADHK_Bi2Se3.100
# x ._ADHK_Bi2Se3.1000
# x ADHK_Bi2Se3.1000
# x ._ADHK_Bi2Se3.1001
# x ADHK_Bi2Se3.1001
# x ._ADHK_Bi2Se3.1002
# x ADHK_Bi2Se3.1002
# x ._ADHK_Bi2Se3.1003
# x ADHK_Bi2Se3.1003
# x ._ADHK_Bi2Se3.1004
# x ADHK_Bi2Se3.1004
# x ._ADHK_Bi2Se3.1005
# x ADHK_Bi2Se3.1005
# x ._ADHK_Bi2Se3.1006
# x ADHK_Bi2Se3.1006
# x ._ADHK_Bi2Se3.1007
# x ADHK_Bi2Se3.1007
# x ._ADHK_Bi2Se3.1008
# x ADHK_Bi2Se3.1008
# x ._ADHK_Bi2Se3.1009
# x ADHK_Bi2Se3.1009
# x ._ADHK_Bi2Se3.101
# x ADHK_Bi2Se3.101
# x ._ADHK_Bi2Se3.1010
# x ADHK_Bi2Se3.1010
# x ._ADHK_Bi2Se3.1011
# x ADHK_Bi2Se3.1011
# x ._ADHK_Bi2Se3.1012
# x ADHK_Bi2Se3.1012
# x ._ADHK_Bi2Se3.1013
# x ADHK_Bi2Se3.1013
# x ._ADHK_Bi2Se3.1014
# x ADHK_Bi2Se3.1014
# x ._ADHK_Bi2Se3.1015
# x ADHK_Bi2Se3.1015
# x ._ADHK_Bi2Se3.1016
# x ADHK_Bi2Se3.1016
# x ._ADHK_Bi2Se3.1017
# x ADHK_Bi2Se3.1017
# x ._ADHK_Bi2Se3.1018
# x ADHK_Bi2Se3.1018
# x ._ADHK_Bi2Se3.1019
# x ADHK_Bi2Se3.1019
# x ._ADHK_Bi2Se3.102
# x ADHK_Bi2Se3.102
# x ._ADHK_Bi2Se3.1020
# x ADHK_Bi2Se3.1020
# x ._ADHK_Bi2Se3.1021
# x ADHK_Bi2Se3.1021
# x ._ADHK_Bi2Se3.1022
# x ADHK_Bi2Se3.1022
# x ._ADHK_Bi2Se3.1023
# x ADHK_Bi2Se3.1023
# x ._ADHK_Bi2Se3.1024
# x ADHK_Bi2Se3.1024
# x ._ADHK_Bi2Se3.1025
# x ADHK_Bi2Se3.1025
# x ._ADHK_Bi2Se3.1026
# x ADHK_Bi2Se3.1026
# x ._ADHK_Bi2Se3.1027
# x ADHK_Bi2Se3.1027
# x ._ADHK_Bi2Se3.1028
# x ADHK_Bi2Se3.1028
# x ._ADHK_Bi2Se3.1029
# x ADHK_Bi2Se3.1029
# x ._ADHK_Bi2Se3.103
# x ADHK_Bi2Se3.963
# x ._ADHK_Bi2Se3.964
# x ADHK_Bi2Se3.964
# x ._ADHK_Bi2Se3.965
# x ADHK_Bi2Se3.965
# x ._ADHK_Bi2Se3.966
# x ADHK_Bi2Se3.966
# x ._ADHK_Bi2Se3.967
# x ADHK_Bi2Se3.967
# x ._ADHK_Bi2Se3.968
# x ADHK_Bi2Se3.968
# x ._ADHK_Bi2Se3.969
# x ADHK_Bi2Se3.969
# x ._ADHK_Bi2Se3.97
# x ADHK_Bi2Se3.97
# x ._ADHK_Bi2Se3.970
# x ADHK_Bi2Se3.970
# x ._ADHK_Bi2Se3.971
# x ADHK_Bi2Se3.971
# x ._ADHK_Bi2Se3.972
# x ADHK_Bi2Se3.972
# x ._ADHK_Bi2Se3.973
# x ADHK_Bi2Se3.973
# x ._ADHK_Bi2Se3.974
# x ADHK_Bi2Se3.974
# x ._ADHK_Bi2Se3.975
# x ADHK_Bi2Se3.975
# x ._ADHK_Bi2Se3.976
# x ADHK_Bi2Se3.976
# x ._ADHK_Bi2Se3.977
# x ADHK_Bi2Se3.977
# x ._ADHK_Bi2Se3.978
# x ADHK_Bi2Se3.978
# x ._ADHK_Bi2Se3.979
# x ADHK_Bi2Se3.979
# x ._ADHK_Bi2Se3.98
# x ADHK_Bi2Se3.98
# x ._ADHK_Bi2Se3.980
# x ADHK_Bi2Se3.980
# x ._ADHK_Bi2Se3.981
# x ADHK_Bi2Se3.981
# x ._ADHK_Bi2Se3.982
# x ADHK_Bi2Se3.982
# x ._ADHK_Bi2Se3.983
# x ADHK_Bi2Se3.983
# x ._ADHK_Bi2Se3.984
# x ADHK_Bi2Se3.984
# x ._ADHK_Bi2Se3.985
# x ADHK_Bi2Se3.985
# x ._ADHK_Bi2Se3.986
# x ADHK_Bi2Se3.986
# x ._ADHK_Bi2Se3.987
# x ADHK_Bi2Se3.987
# x ._ADHK_Bi2Se3.988
# x ADHK_Bi2Se3.988
# x ._ADHK_Bi2Se3.989
# x ADHK_Bi2Se3.989
# x ._ADHK_Bi2Se3.99
# x ADHK_Bi2Se3.99
# x ._ADHK_Bi2Se3.990
# x ADHK_Bi2Se3.990
# x ._ADHK_Bi2Se3.991
# x ADHK_Bi2Se3.991
# x ._ADHK_Bi2Se3.992
# x ADHK_Bi2Se3.992
# x ._ADHK_Bi2Se3.993
# x ADHK_Bi2Se3.993
# x ._ADHK_Bi2Se3.994
# x ADHK_Bi2Se3.994
# x ._ADHK_Bi2Se3.995
# x ADHK_Bi2Se3.995
# x ._ADHK_Bi2Se3.996
# x ADHK_Bi2Se3.996
# x ._ADHK_Bi2Se3.997
# x ADHK_Bi2Se3.997
# x ._ADHK_Bi2Se3.998
# x ADHK_Bi2Se3.998
# x ._ADHK_Bi2Se3.999
# x ADHK_Bi2Se3.999

# %%
plt.close()
fig, axs = plt.subplots(2, 7, figsize=(20, 8))
for index, i in enumerate([0, 500, 1000, 1500, 2000, 2500, 2763]):    
    atoms, metadata, element = parse_xyz(f'New_Bi2Se3_layered/ADHK_Bi2Se3.{i}', element_specified=False)
    # need to specify atoms. 1 is Bi and 2 is Se
    atoms[atoms[:, 0] == 1, 0] = 82 # Bi
    atoms[atoms[:, 0] == 2, 0] = 33 # Se
    poss = [[0,0]] # these are all in Angstroms, assuming center of the potential slice is at (0,0). if you don't specify poss, it will default to [[0,0]]. (single Cbed at the center)

    cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = jnp.array([0,0,1]), theta = 0, pixel_size = 0.1, kirkland_jax=kirkland_jax
                                                                                    , poss = poss )
    for cbed_pattern in cbed_patterns.data_array:
        #fig, axs = plt.subplots(2,1, figsize=(4,9))
        array_center = [cbed_pattern.shape[0] // 2, cbed_pattern.shape[1] // 2]
        axs[0, index].scatter(atoms[:,1], atoms[:,2], c=atoms[:,0], cmap='viridis', s=100, alpha=0.6)
        axs[0, index].set_aspect('equal')
        axs[1, index].imshow(contrast_stretch(cbed_pattern[array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
        axs[1, index].set_axis_off()
        axs[0, index].set_title(f'timstep {i}')
# Out:
#   Cell In[2], line 11
#     , poss = poss )
#     ^
# SyntaxError: invalid syntax

# %%
plt.close()
fig, axs = plt.subplots(2, 7, figsize=(20, 8))
for index, i in enumerate([0, 500, 1000, 1500, 2000, 2500, 2763]):    
    atoms, metadata, element = parse_xyz(f'New_Bi2Se3_layered/ADHK_Bi2Se3.{i}', element_specified=False)
    # need to specify atoms. 1 is Bi and 2 is Se
    atoms[atoms[:, 0] == 1, 0] = 82 # Bi
    atoms[atoms[:, 0] == 2, 0] = 33 # Se
    poss = [[0,0]] # these are all in Angstroms, assuming center of the potential slice is at (0,0). if you don't specify poss, it will default to [[0,0]]. (single Cbed at the center)

    cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = jnp.array([0,1,1]), theta = 0, pixel_size = 0.1, kirkland_jax=kirkland_jax, poss = poss )
    for cbed_pattern in cbed_patterns.data_array:
        #fig, axs = plt.subplots(2,1, figsize=(4,9))
        array_center = [cbed_pattern.shape[0] // 2, cbed_pattern.shape[1] // 2]
        axs[0, index].scatter(test_rotated_coords[:,1], test_rotated_coords[:,2], c=test_rotated_coords[:,0], cmap='viridis', s=16, alpha=0.6)
        axs[0, index].set_aspect('equal')
        axs[1, index].imshow(contrast_stretch(cbed_pattern[array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
        axs[1, index].set_axis_off()
        axs[0, index].set_title(f'timstep {i}')
# Out:
# Time taken for preprocessing: 20.670251846313477 seconds
# time taken for cbed calculation: 2.023257255554199 seconds
# Time taken for preprocessing: 9.712869644165039 seconds
# time taken for cbed calculation: 1.725344181060791 seconds
# Time taken for preprocessing: 9.358197927474976 seconds
# time taken for cbed calculation: 1.5236742496490479 seconds
# Time taken for preprocessing: 8.041691064834595 seconds
# time taken for cbed calculation: 1.2464468479156494 seconds
# Time taken for preprocessing: 7.088953256607056 seconds
# time taken for cbed calculation: 1.1938388347625732 seconds
# Time taken for preprocessing: 12.955317974090576 seconds
# time taken for cbed calculation: 5.034358263015747 seconds
# Time taken for preprocessing: 7.060401916503906 seconds
# time taken for cbed calculation: 2.00506854057312 seconds

# %%
atoms_1800 = jnp.asarray(parse_xyz('Jul12_2025_Bi2Se3/Jul12_2025_Bi2Se3.1800', element_specified=False)[0], dtype=jnp.float32)
atoms_1800[atoms_1800[:, 0] == 1, 0] = 82 # Bi
atoms_1800[atoms_1800[:, 0] == 2, 0] = 33 # Se
# Out:
# array([[82.     ,  2.74205,  2.10698,  2.35506],
#        [82.     ,  6.67029,  3.16614,  2.48363],
#        [82.     ,  2.11199,  4.26303,  5.72901],
#        ...,
#        [33.     , 16.0491 , 11.0023 , 37.0122 ],
#        [33.     , 14.5183 , 13.9884 , 40.1823 ],
#        [82.     , 14.4982 , 16.2708 , 38.4504 ]], shape=(334, 4))

# %%
pixel_size = 0.1 #Angstroms
element_IDS = set([33,82])
kirkland_potentials = {}
for element_ID in element_IDS:
    potential = atomic_potential(
        atom_no=int(element_ID),
        pixel_size=pixel_size,
        sampling=16,
        potential_extent=4,
        datafile="C:/users/zwx/Downloads/Kirkland_Potentials.npy",
    )
    kirkland_potentials[int(element_ID)] = potential


kirkland_jax = jnp.asarray([kirkland_potentials[int(el)] for el in element_IDS])
#for ei, element_ID in enumerate(element_IDS):
    #atoms[atoms[:,0] == element_ID, 0] = ei
# Out:
# finalsize [80 80]
# sspot.shape (1280, 1280)
# finalsize [80 80]
# sspot.shape (1280, 1280)

# %%
poss = [[0,0], [-5, 5], [5,5]] # these are all in Angstroms, assuming center of the potential slice is at (0,0). if you don't specify poss, it will default to [[0,0]]. (single Cbed at the center)

cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = jnp.array([0,0,1]), theta = jnp.pi/4, pixel_size = 0.1, kirkland_jax=kirkland_jax, poss = poss )
# Out:
# Time taken for preprocessing: 6.411423683166504 seconds
# time taken for cbed calculation: 1.8921546936035156 seconds

# %%
import matplotlib.pyplot as plt
for ci, cbed_pattern in enumerate(cbed_patterns.data_array):
    #print(cbed_pattern.data_array.shape)
    fig, axs = plt.subplots(1, 2, figsize=(9,4))
    array_center = [cbed_pattern.shape[0] // 2, cbed_pattern.shape[1] // 2]
    #axs[si,1].imshow(np.log10(cbed_pattern.data_array[array_center[0]-50:array_center[1]+50, array_center[0]-50:array_center[1]+50]), cmap='gray')
    #axs[si,1].imshow(cbed_pattern.data_array, cmap='gray')

    axs[0].scatter(test_rotated_coords[:,1], test_rotated_coords[:,2], c=test_rotated_coords[:,0], cmap='viridis', s=10, alpha=0.6)
    axs[0].set_aspect('equal')
    axs[0].scatter(poss[ci][0], poss[ci][1], c='red', s=10, marker='x', label='Probe Position')
    axs[1].imshow(contrast_stretch(cbed_pattern[array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
    axs[1].set_axis_off()
    plt.tight_layout()

# %%
#for zone_hkl in [[0,0,1],[1,0,1],  [0,1,1], [1,1,1], [1, 0, 2], [0,1,2], [1,1,2]]:
all_test_rotated_coords = []
for zone_hkl in [[0,0,1],[0,1,2]]:
    cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = jnp.array(zone_hkl), theta = 0, pixel_size = 0.1, kirkland_jax=kirkland_jax)
    for cbed_pattern in cbed_patterns.data_array:
        fig, axs = plt.subplots(2,1, figsize=(4,9))
        array_center = [cbed_pattern.shape[0] // 2, cbed_pattern.shape[1] // 2]
        axs[0].scatter(atoms[:,1], atoms[:,2], c=atoms[:,0], cmap='viridis', s=20, alpha=0.6)
        axs[0].set_aspect('equal')
        axs[1].imshow(contrast_stretch(cbed_pattern[array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
        axs[1].set_axis_off()
        axs[1].set_title(f"Zone axis: {zone_hkl}")
        plt.tight_layout()
        all_test_rotated_coords.append(test_rotated_coords)
# Out:
# Time taken for preprocessing: 12.976742029190063 seconds
# time taken for cbed calculation: 1.4214341640472412 seconds
# Time taken for preprocessing: 12.525103092193604 seconds
# time taken for cbed calculation: 3.1910438537597656 seconds

# %%
colors = {82: 'red', 33: 'blue'}
for trci, test_rotated_coords in enumerate(all_test_rotated_coords:
    fig, axs = plt.subplots(1,2, figsize=(9,4))
    axs[0].scatter(test_rotated_coords[:,1], test_rotated_coords[:,2], c = [colors[int(t)] for t in test_rotated_coords[:,0]] , s=9, alpha=0.6)
    axs[0].set_aspect('equal')
    axs[1].imshow(contrast_stretch(cbed_patterns.data_array[0][array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
    axs[1].set_axis_off()

# %%
from tqdm import tqdm
atoms, metadata, element = parse_xyz(f'New_Bi2Se3_layered/ADHK_Bi2Se3.{1}', element_specified=False)
    # need to specify atoms. 1 is Bi and 2 is Se
atoms[atoms[:, 0] == 1, 0] = 82 # Bi
atoms[atoms[:, 0] == 2, 0] = 33 # Se
poss = [[0,0]] # these are all in Angstroms, assuming center of the potential slice is at (0,0). if you don't specify poss, it will default to [[0,0]]. (single Cbed at the center)

for zone_hkl in tqdm([[0,0,1],[0,1,2]]):
    cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = jnp.array(zone_hkl), theta = 0, pixel_size = 0.1, kirkland_jax=kirkland_jax, poss = poss, threshold_A  = 5)
#    for cbed_pattern in cbed_patterns.data_array:
#        fig, axs = plt.subplots(2,1, figsize=(4,9))
#        array_center = [cbed_pattern.shape[0] // 2, cbed_pattern.shape[1] // 2]
#        axs[0].scatter(atoms[:,1], atoms[:,2], c=atoms[:,0], cmap='viridis', s=20, alpha=0.6)
#        axs[0].set_aspect('equal')
#        axs[1].imshow(contrast_stretch(cbed_pattern[array_center[0]-75:array_center[0]+75, array_center[1]-75:array_center[1]+75],2,99), cmap='gray')
#        axs[1].set_axis_off()
#        axs[1].set_title(f"Zone axis: {zone_hkl}")
#        plt.tight_layout()
#        all_test_rotated_coords.append(test_rotated_coords)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Time taken for preprocessing: 9.800247430801392 seconds
#  50%|█████     | 1/2 [00:11<00:11, 11.36s/it]
# time taken for cbed calculation: 1.5036463737487793 seconds
# Time taken for preprocessing: 9.539222240447998 seconds
# 100%|██████████| 2/2 [00:22<00:00, 11.18s/it]
# time taken for cbed calculation: 1.3809795379638672 seconds

# %%
cbed_patterns.calib_x
# Out:
# Array([0.01792115], dtype=float64)

# %%
cbed_patterns.data_array.shape
# Out:
# (1, 558, 558)

# %%
for cbed in cbed_patterns.data_array:
    plt.imshow(contrast_stretch(cbed,2,99), cmap='gray')
    plt.axis('off')
    plt.show()

# %%
import h5py
import numpy as np
def save_cbed_data(h5_filename, entries):
    """
    Save multiple CBED data entries to an HDF5 file.

    Parameters:
    - h5_filename: str, path to the output h5 file.
    - entries: list of dicts, each dict contains keys:
        - "cbed": np.ndarray (128x128)
        - "filename": str
        - "zone_axis": np.ndarray
        - "position": np.ndarray
        - "rotation": float
        - "crop": list or tuple or dict (any serializable info about cropping)
        - "scale": float
    """

    with h5py.File(h5_filename, "w") as f:
        for i, entry in enumerate(entries):
            group = f.create_group(f"entry_{i}")

            # Store cbed array
            group.create_dataset("cbed", data=entry["cbed"], dtype='float32')

            # Store strings as attributes (h5py needs strings encoded or use attrs)
            group.attrs["filename"] = entry["filename"]

            # Store arrays as datasets
            group.create_dataset("zone_axis", data=entry["zone_axis"])
            group.create_dataset("position", data=entry["position"])

            # Store scalar floats as attributes
            group.attrs["rotation"] = entry["rotation"]
            group.attrs["scale"] = entry["scale"]

            # Store crop info - if it's array-like, save as dataset; if complex, save as attribute string
            crop = entry["crop"]
            if isinstance(crop, (list, tuple, np.ndarray)):
                group.create_dataset("crop", data=crop)
            else:
                # Convert to string if needed
                group.attrs["crop"] = str(crop)

if __name__ == "__main__":
    # Example usage
    example_entry = {
        "cbed": np.random.rand(128, 128).astype(np.float32),
        "filename": "sample.xyz",
        "zone_axis": np.array([1, 0, 0]),
        "position": np.array([10.0, 5.0, 0.0]),
        "rotation": 45.0,
        "crop": [20, 20, 100, 100],  # example crop box (x_start, y_start, width, height)
        "scale": 12.5,
    }

    save_cbed_data("cbed_data.h5", [example_entry])

# %%
cbed_patterns[0]
# Out:
# Array([[[7.33725738e-07, 1.32246383e-06, 2.47519774e-06, ...,
#          2.29148050e-07, 1.06569393e-07, 1.16383061e-06],
#         [7.96969740e-07, 1.13914721e-06, 2.03885368e-06, ...,
#          6.19316243e-07, 5.40747208e-08, 1.14859681e-06],
#         [2.22873296e-07, 3.00382278e-07, 3.04607889e-07, ...,
#          2.57151803e-07, 2.16674912e-07, 7.07095947e-08],
#         ...,
#         [3.57731340e-07, 4.62148627e-08, 1.28892542e-07, ...,
#          2.03502263e-08, 2.24960469e-07, 1.32682504e-06],
#         [5.20983996e-08, 6.59964797e-08, 1.50689551e-07, ...,
#          2.48924207e-09, 1.45017315e-08, 4.97326788e-08],
#         ...,
#         [2.85063629e-09, 4.00858112e-08, 8.21320462e-08, ...,
#          9.53837939e-08, 4.53928923e-08, 3.01836531e-08],
#         [7.66639260e-08, 5.47663156e-08, 2.51596091e-07, ...,
#          2.15653241e-07, 2.14530378e-07, 1.19175400e-07],
#         [5.57832423e-09, 1.08775319e-07, 8.98505649e-08, ...,
#          5.74656493e-08, 5.15963770e-09, 6.48238011e-08]]], dtype=float64)

# %%
h5_filename = 'cbed_data_test.h5'
filenames  = [f'New_Bi2Se3_layered/ADHK_Bi2Se3.{i}' for i in [2500, 2600]]
zone_axes = [jnp.array([0,0,1]), jnp.array([0,1,2])]
positions = jnp.array([[0,0]]) # these are all in Angstroms, assuming center of the potential slice is at (0,0). if you don't specify poss, it will default to [[0,0]]. (single Cbed at the center)
entries = []
for fi, filename in tqdm(enumerate(filenames)):
    atoms, metadata, element = parse_xyz(filename, element_specified=False)
    atoms[atoms[:, 0] == 1, 0] = 82 # Bi
    atoms[atoms[:, 0] == 2, 0] = 33 # Se
    for zone_axis in zone_axes:
        for pos in positions:
            for rot in np.random.uniform(0, 2 * jnp.pi, 2):  # Random rotation

                cbed_patterns, slices, test_rotated_coords, test_rotated_cells = overall_wrapper(atoms, metadata, zone_hkl = zone_axis, theta = rot, pixel_size = 0.1, kirkland_jax=kirkland_jax, poss = jnp.array([pos]), threshold_A = 5)
                cbed = np.array(cbed_patterns.data_array[0]) # Assuming you want the first pattern
                cbed_center = np.array([cbed.shape[0] // 2, cbed.shape[1] // 2])
                crop_shift = np.random.randint(-10, 10, size=2)  # Random crop shiftm   
                crop_size = 128
                cbed_cropped = cbed[cbed_center[0]-crop_size//2 + crop_shift[0]:cbed_center[0]+crop_size//2 + crop_shift[0],
                                    cbed_center[1]-crop_size//2 + crop_shift[1]:cbed_center[1]+crop_size//2 + crop_shift[1]]
                scale = np.array([cbed_patterns.calib_x, cbed_patterns.calib_y])
                entry = {
                    "cbed": cbed_cropped.astype(np.float16),
                    "filename": filename,
                    "zone_axis": np.array(zone_axis),
                    "position": np.array(pos),
                    "rotation": rot,  # Store only one rotation angle for simplicity
                    "crop": [int(crop_shift[0]), int(crop_shift[1]), crop_size, crop_size],  # example crop box (x_start, y_start, width, height)
                    "scale": scale
                }
                entries.append(entry)

save_cbed_data(h5_filename, entries)
# Out:
# 0it [00:00, ?it/s]
# Time taken for preprocessing: 11.056737422943115 seconds
# time taken for cbed calculation: 2.1279618740081787 seconds
# Time taken for preprocessing: 11.433436870574951 seconds
# time taken for cbed calculation: 9.163580894470215 seconds
# Time taken for preprocessing: 27.047746658325195 seconds
# time taken for cbed calculation: 2.3935420513153076 seconds
# Time taken for preprocessing: 9.680306196212769 seconds
# 1it [01:15, 75.41s/it]
# time taken for cbed calculation: 1.8849151134490967 seconds
# Time taken for preprocessing: 10.196092367172241 seconds
# time taken for cbed calculation: 1.9117205142974854 seconds
# Time taken for preprocessing: 9.155947208404541 seconds
# time taken for cbed calculation: 1.4674880504608154 seconds
# Time taken for preprocessing: 9.304780006408691 seconds
# time taken for cbed calculation: 1.2201602458953857 seconds
# Time taken for preprocessing: 9.975406169891357 seconds
# time taken for cbed calculation: 6.855719089508057 seconds
# 2it [02:06, 63.06s/it]

# %%
cbeds = []
with open('cbed_data_test.h5', 'rb') as f:
    with h5py.File(f, 'r') as h5_file:
        for key in h5_file.keys():
            print(f"Key: {key}")
            group = h5_file[key]
            print(f"  Filename: {group.attrs['filename']}")
            print(f"  Zone Axis: {group['zone_axis'][:]}")
            print(f"  Position: {group['position'][:]}")
            print(f"  Rotation: {group.attrs['rotation']}")
            print(f"  Crop: {group['crop'][:]}")
            print(f"  Scale: {group.attrs['scale']}")
            cbeds.append(group['cbed'][:])
# Out:
# Key: entry_0
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2500
#   Zone Axis: [0 0 1]
#   Position: [0 0]
#   Rotation: 0.4064033244074306
#   Crop: [ -1  -6 128 128]
#   Scale: [[0.01642036]
#  [0.01642036]]
# Key: entry_1
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2500
#   Zone Axis: [0 0 1]
#   Position: [0 0]
#   Rotation: 1.0271412336542916
#   Crop: [  3   0 128 128]
#   Scale: [[0.01472754]
#  [0.01472754]]
# Key: entry_2
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2500
#   Zone Axis: [0 1 2]
#   Position: [0 0]
#   Rotation: 1.4498569160080146
#   Crop: [  7 -10 128 128]
#   Scale: [[0.0147929]
#  [0.0147929]]
# Key: entry_3
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2500
#   Zone Axis: [0 1 2]
#   Position: [0 0]
#   Rotation: 4.799074031822458
#   Crop: [ -3   5 128 128]
#   Scale: [[0.01724138]
#  [0.01724138]]
# Key: entry_4
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2600
#   Zone Axis: [0 0 1]
#   Position: [0 0]
#   Rotation: 5.752726268949367
#   Crop: [  6   2 128 128]
#   Scale: [[0.01461988]
#  [0.01461988]]
# Key: entry_5
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2600
#   Zone Axis: [0 0 1]
#   Position: [0 0]
#   Rotation: 6.1330734385474095
#   Crop: [  0  -2 128 128]
#   Scale: [[0.01666667]
#  [0.01666667]]
# Key: entry_6
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2600
#   Zone Axis: [0 1 2]
#   Position: [0 0]
#   Rotation: 0.011819373189858366
#   Crop: [ -1   6 128 128]
#   Scale: [[0.01792115]
#  [0.01792115]]
# Key: entry_7
#   Filename: New_Bi2Se3_layered/ADHK_Bi2Se3.2600
#   Zone Axis: [0 1 2]
#   Position: [0 0]
#   Rotation: 2.585125378034899
#   Crop: [  7   1 128 128]
#   Scale: [[0.00969932]
#  [0.00969932]]

# %%
for cbed in cbeds:
    plt.imshow(cbed, cmap='gray')
    plt.axis('off')
    plt.show()
